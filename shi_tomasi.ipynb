# %%
# Cell 1: Import libraries (if not already done)
# %matplotlib inline
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Cell 2: Load and process the image
image = cv2.imread('Screenshot 2025-04-04 at 3.33.02 PM.png')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply Shi-Tomasi Corner Detection
corners = cv2.goodFeaturesToTrack(gray, maxCorners=100, qualityLevel=0.01, minDistance=10)

# Convert corners to integers and mark them
corners = np.int0(corners)
for corner in corners:
    x, y = corner.ravel()
    cv2.circle(image, (x, y), 5, (255, 0, 0), -1) 

# Display the result
plt.figure(figsize=(10, 10))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Shi-Tomasi Corner Detection')
plt.axis('off')
plt.show()

cv2.imwrite('shi_tomasi_corners.jpg', image)
# Out:
# /var/folders/vb/777x3d1n3wldfxwskgf995tc0000gn/T/ipykernel_88930/3883700742.py:15: DeprecationWarning: `np.int0` is a deprecated alias for `np.intp`.  (Deprecated NumPy 1.24)
#   corners = np.int0(corners)
# True
